# %% [markdown]
# # My Jupyter Notebook on IBM Data Science Experience

# %% [markdown]
# **Hagar El**
# Data Scientist

# %% [markdown]
# _I am interested in data science because data science is a hot field with many interesting applications. You can apply mathematical and computational techniques to big data. Visualization of the data allows for clear storytelling of observations._

# %% [markdown]
# ### This sentence creates text of size H3 using markdown
# ### in the cell below we will add 1+1

# %%
1+1
# Out:
# 2

# %% [markdown]
# ---
#
# - bullet list 1
# - list 2
# - list item 3
#
# ---
#
# 1. apple
# 2. orange
# 3. pear
# ---
#
# |X|Y|
# |-|-|
# |1|2|
# |3|2|
#
# ---
#
# ![Image](https://upload.wikimedia.org/wikipedia/commons/thumb/3/38/Jupyter_logo.svg/88px-Jupyter_logo.svg.png "My Jupyter Notebook on IBM Data Science Experience")
#
# ---
# [Google](https://www.google.com "Google page")
#
# ---
# > To be or not to be
# > that is the blockquote
#
# ---
#
# ```python
# print("Hello")
# ```
